# %%
import pandas as pd
import numpy as np

# %%
## 导入
df = pd.read_csv("table2_1.csv")
df
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# f:\program\C202209\2fill0.ipynb Cell 2 in <cell line: 2>()
#       <a href='vscode-notebook-cell:/f%3A/program/C202209/2fill0.ipynb#W1sZmlsZQ%3D%3D?line=0'>1</a> ## 导入
# ----> <a href='vscode-notebook-cell:/f%3A/program/C202209/2fill0.ipynb#W1sZmlsZQ%3D%3D?line=1'>2</a> df = pd.read_csv("table2_1.csv")
#       <a href='vscode-notebook-cell:/f%3A/program/C202209/2fill0.ipynb#W1sZmlsZQ%3D%3D?line=2'>3</a> df
#
# File e:\download\python\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# ...

# %%
df.fillna(0)
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df = df.fillna(value=0)
df
# Out:
#       文物采样点  二氧化硅(SiO2)  氧化钠(Na2O)  氧化钾(K2O)  氧化钙(CaO)  氧化镁(MgO)  氧化铝(Al2O3)  \
# 0        01       69.33       0.00      9.99      6.32      0.87        3.93
# 1        02       36.28       0.00      1.05      2.34      1.18        5.73
# 2     03部位1       87.05       0.00      5.19      2.01      0.00        4.06
# 3     03部位2       61.71       0.00     12.37      5.87      1.11        5.50
# 4        04       65.88       0.00      9.67      7.12      1.56        6.44
# ..      ...         ...        ...       ...       ...       ...         ...
# 64  54严重风化点       17.11       0.00      0.00      0.00      1.11        3.65
# 65       55       49.01       2.71      0.00      1.13      0.00        1.45
# 66       56       29.15       0.00      0.00      1.21      0.00        1.85
# 67       57       25.42       0.00      0.00      1.31      0.00        2.18
# 68       58       30.39       0.00      0.34      3.49      0.79        3.52
#
# ...

# %%
df.to_csv("table2_2.csv")
