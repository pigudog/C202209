# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("table1_1.csv")
df
# Out:
#     文物编号 纹饰  类型   颜色 表面风化
# 0      1  C  高钾   蓝绿  无风化
# 1      2  A  铅钡   浅蓝   风化
# 2      3  A  高钾   蓝绿  无风化
# 3      4  A  高钾   蓝绿  无风化
# 4      5  A  高钾   蓝绿  无风化
# 5      6  A  高钾   蓝绿  无风化
# 6      7  B  高钾   蓝绿   风化
# 7      8  C  铅钡    紫   风化
# 8      9  B  高钾   蓝绿   风化
# 9     10  B  高钾   蓝绿   风化
# 10    11  C  铅钡   浅蓝   风化
# 11    12  B  高钾   蓝绿   风化
# 12    13  C  高钾   浅蓝  无风化
# 13    14  C  高钾   深绿  无风化
# 14    15  C  高钾   浅蓝  无风化
# 15    16  C  高钾   浅蓝  无风化
# 16    17  C  高钾   浅蓝  无风化
# 17    18  A  高钾   深蓝  无风化
# 18    19  A  铅钡  NaN   风化
# 19    20  A  铅钡   浅蓝  无风化
# 20    21  A  高钾   蓝绿  无风化
# 21    22  B  高钾   蓝绿   风化
# 22    23  A  铅钡   蓝绿   风化
# 23    24  C  铅钡    紫  无风化
# 24    25  C  铅钡   浅蓝   风化
# 25    26  C  铅钡    紫   风化
# 26    27  B  高钾   蓝绿   风化
# 27    28  A  铅钡   浅蓝   风化
# 28    29  A  铅钡   浅蓝   风化
# 29    30  A  铅钡   深蓝  无风化
# 30    31  C  铅钡    紫  无风化
# 31    32  C  铅钡   浅绿  无风化
# 32    33  C  铅钡   深绿  无风化
# 33    34  C  铅钡   深绿   风化
# ...

# %%
df = df.dropna(axis=0,how="any")
df
# Out:
#     文物编号 纹饰  类型  颜色 表面风化
# 0      1  C  高钾  蓝绿  无风化
# 1      2  A  铅钡  浅蓝   风化
# 2      3  A  高钾  蓝绿  无风化
# 3      4  A  高钾  蓝绿  无风化
# 4      5  A  高钾  蓝绿  无风化
# 5      6  A  高钾  蓝绿  无风化
# 6      7  B  高钾  蓝绿   风化
# 7      8  C  铅钡   紫   风化
# 8      9  B  高钾  蓝绿   风化
# 9     10  B  高钾  蓝绿   风化
# 10    11  C  铅钡  浅蓝   风化
# 11    12  B  高钾  蓝绿   风化
# 12    13  C  高钾  浅蓝  无风化
# 13    14  C  高钾  深绿  无风化
# 14    15  C  高钾  浅蓝  无风化
# 15    16  C  高钾  浅蓝  无风化
# 16    17  C  高钾  浅蓝  无风化
# 17    18  A  高钾  深蓝  无风化
# 19    20  A  铅钡  浅蓝  无风化
# 20    21  A  高钾  蓝绿  无风化
# 21    22  B  高钾  蓝绿   风化
# 22    23  A  铅钡  蓝绿   风化
# 23    24  C  铅钡   紫  无风化
# 24    25  C  铅钡  浅蓝   风化
# 25    26  C  铅钡   紫   风化
# 26    27  B  高钾  蓝绿   风化
# 27    28  A  铅钡  浅蓝   风化
# 28    29  A  铅钡  浅蓝   风化
# 29    30  A  铅钡  深蓝  无风化
# 30    31  C  铅钡   紫  无风化
# 31    32  C  铅钡  浅绿  无风化
# 32    33  C  铅钡  深绿  无风化
# 33    34  C  铅钡  深绿   风化
# 34    35  C  铅钡  浅绿  无风化
# 35    36  C  铅钡  深绿   风化
# 36    37  C  铅钡  深绿  无风化
# ...

# %%
df.to_csv("table1_2.csv",encoding="gb2312",index=False)
